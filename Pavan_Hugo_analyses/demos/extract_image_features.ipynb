# %% [markdown]
# ## Extract image features from a patch

# %%
import numpy as np
import scipy.io as io
import h5py
import deepdish as dd
import dask.array as da
import os

import skimage
from skimage import io, color

import pycircstat as pyc
from scipy import stats

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
h5path = '../../H5data/'
#h5path = '/Volumes/JUICE/lab projects/V4_CNN/V4pydata/H5data/'
Monkey  = 'M2' #choose monkey

fname = os.listdir(h5path + Monkey)
fname = [session for session in fname if '.h5' in session]
thisfile = fname[2]
print fname
# Out:
# ['Bo130828_s92a_v4fv_orig_0005_nev.h5', 'Bo130828_s92a_v4fv_orig_0006_nev.h5', 'Bo130828_s92a_v4fv_orig_0007_nev.h5', 'Bo130828_s92a_v4fv_orig_0008_nev.h5', 'Bo130829_s93a_v4fv_eqlum_0004_nev.h5', 'Bo130829_s94a_v4fv_randlum_0005_nev.h5', 'Bo130829_s94a_v4fv_randlum_0006_nev.h5']

# %% [markdown]
# ### Read in using deepdish

# %%
### Read in using deepdish
dat = dd.io.load(h5path+Monkey+'/'+thisfile)

# %% [markdown]
# ### Manipulate spike data

# %%
## Show first ten spike times for unit 5401
dat['spikes']['5401'][:10]
# Out:
# array([ 0.0134    ,  0.04193333,  0.0593    ,  0.12966667,  0.3099    ,
#         0.32123333,  0.37343333,  0.38876667,  0.40143333,  0.42673333])

# %%
dat['eyes'][0]['impath']
# Out:
# 'stimuli/M2/Orig'

# %% [markdown]
# ### Define useful functions

# %%
def get_hue_image(I):
    # Convert to Luv
    Luv = color.rgb2luv(I/255.0)
    # Extract hue
    hue = np.arctan2(Luv[:,:,2], Luv[:,:,1])
    return hue

# %%
def visualize_hue_image(I):
    # Convert to Luv
    Luv = color.rgb2luv(I/255.0)
    
    # Assign lum channel to a constant
    Luv[:,:,0] = 60.0*np.ones([Luv.shape[0], Luv.shape[1]])

    # Convert back to RGB just to visualize
    Iviz = color.luv2rgb(Luv)
    
    return Iviz

# %%
def show_hue(ax, hue, Nbins=36, polar=False):
    huehist, bin_edges = np.histogram(hue, bins=Nbins, range=(-np.pi, np.pi))
    
    bin_centers = bin_edges[:Nbins]+(bin_edges[1]-bin_edges[0])/2
    fig = ax.bar(bin_centers, huehist, width=0.2, edgecolor='g', color='g')
    
    bar_colors_rgb = hues_to_rgb(bin_centers)
    for i,j in enumerate(fig):
        j.set_color(bar_colors_rgb[0,i,:]) 
    
    ax.hold
    if polar == True:
        ax.plot(bin_centers, 1.2*np.max(huehist)*np.ones(len(huehist)+1), color='k')
    mean_hue = stats.circmean(hue, high=np.pi, low=-np.pi)
    std_hue = stats.circstd(hue, high=np.pi, low=-np.pi)
    conf_int = np.linspace(mean_hue-std_hue,mean_hue+std_hue, 10)
    
    ax.plot(mean_hue, 1.1*np.max(huehist), '*', color = hues_to_rgb(mean_hue)[0,0,:], markeredgecolor = 'w', markersize=20)
    for i in conf_int:
        ax.plot(i, 1.1*np.max(huehist), '.', color = hues_to_rgb(i)[0,0,:], markeredgecolor = 'w', markersize=7)
    ax.axis('off')

def hues_to_rgb(hue_vector, L = 60.0, scale = 90.0):
    
    hue_vector = np.atleast_2d(hue_vector)
    mean_colors_luv = np.ones([np.shape(hue_vector)[0],np.shape(hue_vector)[1],3])
    mean_colors_luv[:,:,0] = L
    mean_colors_luv[:,:,1] = scale*np.cos(hue_vector)
    mean_colors_luv[:,:,2] = scale*np.sin(hue_vector)
    mean_colors_rgb = color.luv2rgb(mean_colors_luv)
    
    return mean_colors_rgb

# %%
def grid_image(I, gridshape):
    R = gridshape[0]
    C = gridshape[1]
    b_rows = np.int(np.floor(I.shape[0]/R))
    b_cols = np.int(np.floor(I.shape[1]/C))
    Block = np.zeros([R * C, b_rows, b_cols, I.shape[2]])
    count = 0
    for i in range(R):
        for j in range(C):
            Block[count :, :, :] = I[b_rows * i:b_rows * (i+1), b_cols * j:b_cols *(j+1), :]
            count += 1
    return Block

# %% [markdown]
# ### Manipulate image data
# Use this codeblock to loop through fixations

# %%
# Extract a patch of arbitrary radius around a fixation
projectpath = '../..'
#projectpath = '../../../V4pydata/'

fx = 701

# Read in the image
impath = dat['eyes'][fx]['impath']
imname = dat['eyes'][fx]['imname']
filename = projectpath+'/'+impath+'/'+imname
I = io.imread(filename)

# Pad the image
[H,W,D] = I.shape
I_pad = 128*np.ones([3*H, 3*W, D])
I_pad[H-1:2*H-1,W-1:2*W-1,0] = I[:,:,0]
I_pad[H-1:2*H-1,W-1:2*W-1,1] = I[:,:,1]
I_pad[H-1:2*H-1,W-1:2*W-1,2] = I[:,:,2]

# Get gaze location
r = int(dat['eyes'][fx]['row'])
c = int(dat['eyes'][fx]['col'])

# If gaze is within the image borders
if(r>0 and r<768 and c>0 and c<1024):
    # Extract patch
    R = 200 #radius
    G = np.zeros([2*R, 2*R, 3])
    G = I_pad[r+H-R:r+H+R, c+W-R:c+W+R, :]
    
    # Show patch
    plt.figure(figsize=(20,20))
    plt.subplot(1,3,1)
    plt.imshow(I)
    plt.axis('off')
    plt.subplot(1,3,2)
    plt.imshow(np.uint8(G))
    plt.axis('off')
    plt.show()
    
    # Extract hsl features
else:
    print r,c
    print 'outside'

# %% [markdown]
# ### Extract hue and map it back to rgb for visualization

# %%
# Extract hue
hue = get_hue_image(G)

# Visualize hue image
Gviz = visualize_hue_image(G)

# Show images
plt.figure(figsize=(20,20))
plt.subplot(121)
plt.imshow(np.uint8(G))
plt.axis('off')

plt.subplot(122)
plt.imshow(np.uint8(255.0*Gviz))
plt.axis('off')
plt.show()

# %% [markdown]
# ### Grid the image and extract hue features from the grid

# %%
# Grid the image and check if it's correct
G_block = grid_image(G, [4, 4])
plt.figure(figsize=(20,20))
for grd in range(1, 17):
    plt.subplot(4,4,grd)
    #Gviz = visualize_hue_image(G_block[grd-1,:,:,:])
    plt.imshow(np.uint8(G_block[grd-1,:,:,:]))
    plt.axis('off')
plt.show()

# %%
# Grid the image and check if it's correct
G_block = grid_image(G, [4, 4])
plt.figure(figsize=(20,20))
for grd in range(1, 17):
    plt.subplot(4,4,grd)
    Gviz = visualize_hue_image(G_block[grd-1,:,:,:])
    plt.imshow(np.uint8(255.0*Gviz))
    plt.axis('off')
plt.show()

# %%
# Compute histogram and circular mean of hue for gridded image
plt.figure(figsize=(15,15))
for grd in range(1, 17):
    hue = get_hue_image(G_block[grd-1,:,:,:])
    ax = plt.subplot(4,4,grd, polar=True)
    show_hue(ax, hue)
plt.show()

# %% [markdown]
# ### Checking some color space things

# %%
imtest = np.zeros([2,2,3])
imtest[0,0,:] = [0.1, 0.2, 0.3]
imtest[0,1,:] = [0.3, 0.2, 0.1]
imtest[1,0,:] = [0.3, 0.2, 0.1]
imtest[1,1,:] = [0.3, 0.2, 0.1]
# %timeit color.rgb2luv(imtest)
# %timeit color.rgb2hsv(imtest)
# Out:
# The slowest run took 5.33 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 128 µs per loop
# 10000 loops, best of 3: 109 µs per loop
